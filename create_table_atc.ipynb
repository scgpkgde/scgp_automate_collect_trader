# %% [markdown]
# CREATE TABLE - PRODUCT

# %%
# %sql
# CREATE TABLE scgp_edl_dev_uat.dev_scgp_edl_staging.ext_tradereport_thailand_imp_exp_product(
#   product VARCHAR(200) NOT NULL,
#   amount_thb DECIMAL(22,4),
#   expansion_rate DECIMAL(18,4),
#   proportion DECIMAL(18,4),
#   data_month VARCHAR(2) NOT NULL,
#   data_year VARCHAR(4) NOT NULL,
#   type VARCHAR(6) NOT NULL,
#   start_date TIMESTAMP NOT NULL,
#   end_date TIMESTAMP NOT NULL,
#   active_status BOOLEAN NOT NULL,
#   src_hash_key VARCHAR(32) NOT NULL,
#   src_hash VARCHAR(32),
#   CONSTRAINT `ext_tradereport_th_product` PRIMARY KEY (`product`, `data_month`, `data_year`,`type`))
# USING delta
# LOCATION 'abfss://scgpdldev@scgpkgdldevhot.dfs.core.windows.net/EDW_DATA_STG/ext_tradereport/ext_tradereport_thailand_imp_exp_product'
# TBLPROPERTIES (
#   'delta.checkpoint.writeStatsAsJson' = 'false',
#   'delta.checkpoint.writeStatsAsStruct' = 'true',
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7')

# %% [markdown]
# CREATE TABLE - COUNTRY

# %%
# %sql
# CREATE TABLE scgp_edl_dev_uat.dev_scgp_edl_staging.ext_tradereport_thailand_imp_exp_country(
#   country VARCHAR(100) NOT NULL,
#   amount_thb DECIMAL(22,4),
#   expansion_rate DECIMAL(18,4),
#   proportion DECIMAL(18,4),
#   data_month VARCHAR(2) NOT NULL,
#   data_year VARCHAR(4) NOT NULL,
#   type VARCHAR(6) NOT NULL,
#   start_date TIMESTAMP NOT NULL,
#   end_date TIMESTAMP NOT NULL,
#   active_status BOOLEAN NOT NULL,
#   src_hash_key VARCHAR(32) NOT NULL,
#   src_hash VARCHAR(32),
#   CONSTRAINT `ext_tradereport_th_country` PRIMARY KEY (`country`, `data_month`, `data_year`,`type`))
# USING delta
# LOCATION 'abfss://scgpdldev@scgpkgdldevhot.dfs.core.windows.net/EDW_DATA_STG/ext_tradereport/ext_tradereport_thailand_imp_exp_country'
# TBLPROPERTIES (
#   'delta.checkpoint.writeStatsAsJson' = 'false',
#   'delta.checkpoint.writeStatsAsStruct' = 'true',
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7')

# %% [markdown]
# CREATE TABLE - HS CODE

# %%
# %sql
# CREATE TABLE scgp_edl_dev_uat.dev_scgp_edl_staging.ext_tradereport_thailand_imp_exp_hs_code(
#   country VARCHAR(100) NOT NULL,
#   quantity_units DECIMAL(22,4),
#   amount_thb DECIMAL(22,4),
#   proportion DECIMAL(18,4),
#   hs_code VARCHAR(15) NOT NULL,
#   data_month VARCHAR(2) NOT NULL,
#   data_year VARCHAR(4) NOT NULL,
#   type VARCHAR(6) NOT NULL,
#   start_date TIMESTAMP NOT NULL,
#   end_date TIMESTAMP NOT NULL,
#   active_status BOOLEAN NOT NULL,
#   src_hash_key VARCHAR(32) NOT NULL,
#   src_hash VARCHAR(32),
#   CONSTRAINT `ext_tradereport_th_hscode` PRIMARY KEY (`country`, `hs_code`,`data_month`, `data_year`,`type`))
# USING delta
# LOCATION 'abfss://scgpdldev@scgpkgdldevhot.dfs.core.windows.net/EDW_DATA_STG/ext_tradereport/ext_tradereport_thailand_imp_exp_hs_code'
# TBLPROPERTIES (
#   'delta.checkpoint.writeStatsAsJson' = 'false',
#   'delta.checkpoint.writeStatsAsStruct' = 'true',
#   'delta.enableDeletionVectors' = 'true',
#   'delta.feature.deletionVectors' = 'supported',
#   'delta.feature.invariants' = 'supported',
#   'delta.minReaderVersion' = '3',
#   'delta.minWriterVersion' = '7')
